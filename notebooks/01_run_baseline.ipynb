# %% [markdown]
# # PIRBN Baseline Experiments
#
# 本 Notebook 运行论文中 4 组默认实验：
# - µ = 4, right_by = 0, activation = tanh
# - µ = 8, right_by = 0, activation = tanh
# - µ = 4, right_by = 100, activation = gaussian
# - µ = 8, right_by = 100, activation = gaussian
#
# 结果会生成 Fig.1–Fig.6，可用于对照论文。

# %%
import sys
sys.path.append("../src/PIRBN")

from main import sine_function_main

experiments = [
    (4, 0, "tanh"),
    (8, 0, "tanh"),
    (4, 100, "gaussian"),
    (8, 100, "gaussian"),
]
for mu, right_by, act in experiments:
    print(f"\n=== Running µ={mu}, right_by={right_by}, activation={act} ===")
    sine_function_main(mu=mu, right_by=right_by, activation_function=act)
# Out:
# Iter :  0 	loss :  97745.5703125 	boundary loss :  0.2289004623889923 	eq loss :  97745.34375
# 	a_g = 1.7373274564743042 	a_b = 2.3562495708465576
# Iter :  100 	loss :  169596.40625 	boundary loss :  0.25770553946495056 	eq loss :  97618.7890625
# 	a_g = 1.643782615661621 	a_b = 2.5533196926116943
# Iter :  200 	loss :  160109.625 	boundary loss :  1.0708779096603394 	eq loss :  97401.5
# 	a_g = 1.4623993635177612 	a_b = 3.162632703781128
# Iter :  300 	loss :  141938.78125 	boundary loss :  3.4223387241363525 	eq loss :  97051.4375
# 	a_g = 1.307265043258667 	a_b = 4.254518985748291
# Iter :  400 	loss :  126324.0234375 	boundary loss :  7.310575485229492 	eq loss :  96608.5078125
# 	a_g = 1.205701231956482 	a_b = 5.861419677734375
# Iter :  500 	loss :  115988.5625 	boundary loss :  10.773262023925781 	eq loss :  96147.7109375
# 	a_g = 1.1468868255615234 	a_b = 7.80795955657959
# Iter :  600 	loss :  109865.4921875 	boundary loss :  11.734317779541016 	eq loss :  95714.65625
# ...

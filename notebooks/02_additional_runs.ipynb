# %% [markdown]
# # Additional Runs: Different Frequencies
#
# 为了满足“至少两个数据集”要求，我们在正弦驱动 PDE 上再跑两组不同频率 µ 实验：
# - µ = 2, right_by = 0, activation = gaussian
# - µ = 16, right_by = 0, activation = gaussian

# %%
import sys
# 确保能找到官方代码
sys.path.append("../src/PIRBN")  

from main import sine_function_main

extra_experiments = [
    (2, 0, "gaussian"),
    (16, 0, "gaussian"),
]

for mu, right_by, act in extra_experiments:
    print(f"\n=== Running µ={mu}, right_by={right_by}, activation={act} ===")
    sine_function_main(mu=mu, right_by=right_by, activation_function=act)
# Out:
# === Running µ=2, right_by=0, activation=gaussian ===
# Iter :  0 	loss :  8973.888671875 	boundary loss :  0.07171034812927246 	eq loss :  8973.8173828125
# 	a_g = 1.0000332593917847 	a_b = 30135.55859375
# Iter :  100 	loss :  2613.995361328125 	boundary loss :  0.002059679012745619 	eq loss :  2551.8408203125
# 	a_g = 1.0000333786010742 	a_b = 30008.8515625
# W0424 13:21:47.126883 194949 multiply_fwd_func.cc:64] got different data type, run type protmotion automatically, this may cause data type been changed.
# Iter :  200 	loss :  667.3118896484375 	boundary loss :  0.0004966770065948367 	eq loss :  652.3853759765625
# 	a_g = 1.0000332593917847 	a_b = 30008.68359375
# Iter :  300 	loss :  247.544921875 	boundary loss :  0.00013770916848443449 	eq loss :  243.4043426513672
# 	a_g = 1.0000332593917847 	a_b = 30029.87109375
# Iter :  400 	loss :  148.28131103515625 	boundary loss :  4.8695386794861406e-05 	eq loss :  146.81411743164062
# ...
